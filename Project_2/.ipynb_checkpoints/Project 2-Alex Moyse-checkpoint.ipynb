# %%
import urllib.parse
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Essentially, this data is hosted on Kaggle. In terms of its origin, the data was pulled from IMDb and arranged into two distinct file types: titles.csv and names.csv. The data represents a listing of actors and movies, their respective dates, runtimes, genres etc, as well as how they link together. Set can be found here (https://www.kaggle.com/datasets/rishabjadhav/imdb-actors-and-movies?select=titles.csv)
#
# I wanted to learn more about movies from 2000s onwards. So I first loaded in the data. From there, I proceeded to rip out movies from 2000s onwards that were either horror or fantasy, and did not include shorts. IE get the full feature movies that were horror or fantasy. I expanded the data to make it easy to integrate into a graph database.

# %%
#Load Data
names = pd.read_csv('names.csv')
titles = pd.read_csv('titles.csv')

#Clean Data
titles['startYear'].replace('\\N', pd.NA, inplace=True)
titles['startYear'] = pd.to_numeric(titles['startYear'], errors='coerce')

#Filter Data
filtered_titles = titles[
    (titles['startYear'] >= 2000) &
    (titles['genres'].str.contains('Horror|Fantasy', case=False, na=False)) &
    (titles['titleType'] != 'short')
][['tconst', 'primaryTitle']]


names_expanded = names.assign(tconst=names['knownForTitles'].str.split(',')).explode('tconst') #Take the 
actors_movies = names_expanded.merge(filtered_titles, on='tconst')

#Create Graph
B = nx.Graph()

#Filter for uniqueness (we don't need dupes)
actors = actors_movies['nconst'].unique()
movies = actors_movies['tconst'].unique()

B.add_nodes_from(actors, bipartite=0, type='actor')
B.add_nodes_from(movies, bipartite=1, type='movie')

#Add connections
edges = actors_movies[['nconst', 'tconst']].values.tolist()
B.add_edges_from(edges)

#Show basic info
print(nx.info(B))

#Lets make a clean graph
sample_nodes = list(actors)[:100] + list(movies)[:100]
sample_B = B.subgraph(sample_nodes)
pos = nx.spring_layout(sample_B)
nx.draw(sample_B, pos, with_labels=True, node_size=50, node_color='skyblue', edge_color='gray')
plt.title("Top 100 IMDb Movies and Actors Bipartite Graph")
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 1116063
# Number of edges: 1250076
# Average degree:   2.2402

# %% [markdown]
# Okay this data is too dense to cleanly display, lets try and pear it down to something more manageable as 1116063 nodes is hard to work with quickly. Were going to select the top 250 nodes and look at the interactions between them.

# %%
#Same picking mechanism tuned for 250
actor_degrees = B.degree(actors)
movie_degrees = B.degree(movies)
top_actors = [actor for actor, degree in sorted(actor_degrees, key=lambda x: x[1], reverse=True)[:250]]
top_movies = [movie for movie, degree in sorted(movie_degrees, key=lambda x: x[1], reverse=True)[:250]]

#Make Subgraph
top_nodes = top_actors + top_movies
subgraph_B = B.subgraph(top_nodes)

#Basic Metrics
print(nx.info(subgraph_B))

#Quick visualisation
pos = nx.spring_layout(subgraph_B)
plt.figure(figsize=(12, 12))
nx.draw(subgraph_B, pos, with_labels=False, node_size=20, node_color='skyblue', edge_color='gray')
plt.title("Top 250 IMDb Movies and Actors Bipartite Graph")
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 500
# Number of edges: 365
# Average degree:   1.4600

# %% [markdown]
# Let's make sure there still some connection between movies and actors as I want to have something interesting to explore

# %%
#Check for connection
has_connections = any(edge[0] in top_actors and edge[1] in top_movies or edge[0] in top_movies and edge[1] in top_actors for edge in subgraph_B.edges)
print(f"Subgraph has connections between actors and movies: {has_connections}")

#Get Human Readable stuff
actor_names = names.set_index('nconst')['primaryName'].to_dict()
movie_titles = titles.set_index('tconst')['primaryTitle'].to_dict()

#Show data
print("Sample edges in the subgraph:")
for i, edge in enumerate(subgraph_B.edges(data=True)):
    if i < 10:  #Print basics
        node1, node2 = edge[:2]
        node1_label = actor_names.get(node1, movie_titles.get(node1, node1))
        node2_label = actor_names.get(node2, movie_titles.get(node2, node2))
        print(f"{node1_label} - {node2_label}")
# Out:
# Subgraph has connections between actors and movies: True
# Sample edges in the subgraph:
# Nachiarkovil Durairaj Rangesh - Life of Pi
# Nachiarkovil Durairaj Rangesh - The Mummy: Tomb of the Dragon Emperor
# Once Upon a Time - Leah Fong
# Alister Baxter - Avatar: The Way of Water
# Alister Baxter - Mortal Engines
# Alister Baxter - The Meg
# Wade Beaven - Avatar: The Way of Water
# Eddie Apodaca - Avatar
# Blade: Trinity - Chris Hehn
# Blade: Trinity - Akotene Chanoine

# %% [markdown]
# So we know there are still connections, how do we isolate that pretty little island of interconnectivity in the middle

# %%
# Function to apply the island method
def apply_island_method(G, weight_threshold):
    G = G.copy()
    
    #Remove Edges below weight threshold
    edges_to_remove = [(u, v) for u, v, w in G.edges(data=True) if w.get('weight', 1) < weight_threshold]
    G.remove_edges_from(edges_to_remove)
    
    #Keep largest connected component
    largest_cc = max(nx.connected_components(G), key=len)
    core_subgraph = G.subgraph(largest_cc).copy()
    
    return core_subgraph

#Apply the island method with a weight threshold 
core_subgraph = apply_island_method(subgraph_B, weight_threshold=1)

#Print Basic info
print(nx.info(core_subgraph))

#Make object for labels that is relevent
labels = {node: actor_names.get(node, movie_titles.get(node, node)) for node in core_subgraph.nodes()}

#Visualise slimmed down data
pos = nx.spring_layout(core_subgraph)
plt.figure(figsize=(12, 12))
nx.draw(core_subgraph, pos, labels=labels, node_size=20, node_color='skyblue', edge_color='gray', font_size=8)
plt.title("Core Subgraph of Top 250 IMDb Movies and Actors (Island Method)")
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 221
# Number of edges: 329
# Average degree:   2.9774

# %% [markdown]
# I want to drill more into this. Let's calculate some centrality measures and see what is impactful.

# %%
#Of top 250, lets calc centrality measures
degree_centrality = nx.degree_centrality(core_subgraph)
betweenness_centrality = nx.betweenness_centrality(core_subgraph)
closeness_centrality = nx.closeness_centrality(core_subgraph)
eigenvector_centrality = nx.eigenvector_centrality(core_subgraph)

#Create a df to make it pretty
centrality_df = pd.DataFrame({
    'Node': list(degree_centrality.keys()),
    'Degree Centrality': list(degree_centrality.values()),
    'Betweenness Centrality': list(betweenness_centrality.values()),
    'Closeness Centrality': list(closeness_centrality.values()),
    'Eigenvector Centrality': list(eigenvector_centrality.values())
})

#Map the actual names to the nodes, so that we can read it
centrality_df['Label'] = centrality_df['Node'].map(labels)
centrality_df = centrality_df[['Label', 'Degree Centrality', 'Betweenness Centrality', 'Closeness Centrality', 'Eigenvector Centrality']]
centrality_df
# Out:
#                                                  Label  Degree Centrality  \
# 0                        Nachiarkovil Durairaj Rangesh           0.009091
# 1                                       Fantastic Four           0.004545
# 2                              Lara Croft: Tomb Raider           0.004545
# 3                                         Dan Davidson           0.013636
# 4                                             The Fall           0.004545
# ..                                                 ...                ...
# 216                                     Michal Pokorny           0.009091
# 217                                      Mortal Kombat           0.009091
# 218                                      Marilyn McKay           0.004545
# 219  The Chronicles of Narnia: The Lion, the Witch ...           0.013636
# 220                                         Pál Szûrös           0.009091
#
#      Betweenness Centrality  Closeness Centrality  Eigenvector Centrality
# 0                  0.009091              0.140485            1.546395e-03
# 1                  0.000000              0.121884            4.701085e-05
# 2                  0.000000              0.127389            3.452598e-06
# 3                  0.018140              0.190972            8.376670e-02
# 4                  0.000000              0.128130            3.544533e-05
# ..                      ...                   ...                     ...
# 216                0.027024              0.140485            5.775434e-06
# 217                0.000010              0.176707            2.749983e-02
# 218                0.000000              0.141753            3.217429e-04
# 219                0.018140              0.123526            7.908567e-07
# 220                0.009091              0.118026            1.364270e-05
#
# [221 rows x 5 columns]

# %% [markdown]
# Essentially, this is a sample to see which nodes have high degrees of connection.

# %%
#Let's make metrics
print("Summary Statistics for Centrality Measures:")

# Identify top nodes for each centrality measure
top_degree_centrality = centrality_df.nlargest(10, 'Degree Centrality')
top_betweenness_centrality = centrality_df.nlargest(10, 'Betweenness Centrality')
top_closeness_centrality = centrality_df.nlargest(10, 'Closeness Centrality')
top_eigenvector_centrality = centrality_df.nlargest(10, 'Eigenvector Centrality')

centrality_df.describe()
# Out:
# Summary Statistics for Centrality Measures:
#        Degree Centrality  Betweenness Centrality  Closeness Centrality  \
# count         221.000000              221.000000            221.000000
# mean            0.013534                0.024384              0.165670
# std             0.016630                0.052396              0.034835
# min             0.004545                0.000000              0.083082
# 25%             0.004545                0.000000              0.139241
# 50%             0.009091                0.009091              0.166038
# 75%             0.013636                0.020587              0.191638
# max             0.209091                0.458991              0.238095
#
#        Eigenvector Centrality
# count            2.210000e+02
# mean             3.276009e-02
# std              5.888423e-02
# min              4.357536e-10
# 25%              4.701085e-05
# 50%              2.644788e-03
# 75%              5.422385e-02
# max              6.117093e-01

# %%
top_degree_centrality
# Out:
#                                                  Label  Degree Centrality  \
# 89                            Avatar: The Way of Water           0.209091
# 193                  The Hobbit: An Unexpected Journey           0.072727
# 205                                             Avatar           0.068182
# 9             Pirates of the Caribbean: At World's End           0.059091
# 64                                      Mortal Engines           0.054545
# 121                The Hobbit: The Desolation of Smaug           0.050000
# 167            Star Wars: Episode VIII - The Last Jedi           0.045455
# 37                                             The Meg           0.040909
# 81   Pirates of the Caribbean: The Curse of the Bla...           0.040909
# 58           Shang-Chi and the Legend of the Ten Rings           0.031818
#
#      Betweenness Centrality  Closeness Centrality  Eigenvector Centrality
# 89                 0.458991              0.234792                0.611709
# 193                0.184783              0.233794                0.174118
# 205                0.220047              0.231823                0.102672
# 9                  0.090288              0.210124                0.024556
# 64                 0.012037              0.198377                0.170540
# 121                0.078806              0.220662                0.148908
# 167                0.343072              0.212560                0.008354
# 37                 0.025556              0.201281                0.096134
# 81                 0.055514              0.206573                0.020124
# 58                 0.005326              0.183181                0.093880

# %%
top_betweenness_centrality
# Out:
#                                        Label  Degree Centrality  \
# 89                  Avatar: The Way of Water           0.209091
# 167  Star Wars: Episode VIII - The Last Jedi           0.045455
# 112                           Virgil Manning           0.018182
# 205                                   Avatar           0.068182
# 157                            Sharon McLean           0.013636
# 193        The Hobbit: An Unexpected Journey           0.072727
# 173                            Resident Evil           0.022727
# 22                               Joe Harkins           0.018182
# 98                             Kristos Focas           0.018182
# 68                                   Hellboy           0.018182
#
#      Betweenness Centrality  Closeness Centrality  Eigenvector Centrality
# 89                 0.458991              0.234792                0.611709
# 167                0.343072              0.212560                0.008354
# 112                0.234574              0.190311                0.001353
# 205                0.220047              0.231823                0.102672
# 157                0.199193              0.216110                0.043794
# 193                0.184783              0.233794                0.174118
# 173                0.172687              0.170411                0.000194
# 22                 0.133284              0.206379                0.014822
# 98                 0.106999              0.211538                0.037916
# 68                 0.106832              0.185968                0.002069

# %%
top_closeness_centrality
# Out:
#                                  Label  Degree Centrality  \
# 52                        Andy McLaren           0.018182
# 163                     Melissa Spicer           0.013636
# 89            Avatar: The Way of Water           0.209091
# 193  The Hobbit: An Unexpected Journey           0.072727
# 205                             Avatar           0.068182
# 209                  Stephen E. Rivkin           0.018182
# 104                         Glenn Levy           0.018182
# 95                          Tim Willis           0.013636
# 114                       Gemma Weston           0.013636
# 127                        Cody Dysart           0.013636
#
#      Betweenness Centrality  Closeness Centrality  Eigenvector Centrality
# 52                 0.053650              0.238095                0.137099
# 163                0.042444              0.237581                0.117420
# 89                 0.458991              0.234792                0.611709
# 193                0.184783              0.233794                0.174118
# 205                0.220047              0.231823                0.102672
# 209                0.104925              0.225873                0.100314
# 104                0.024080              0.223577                0.146068
# 95                 0.018934              0.223124                0.123531
# 114                0.018934              0.223124                0.123531
# 127                0.018934              0.223124                0.123531

# %%
top_eigenvector_centrality
# Out:
#                                    Label  Degree Centrality  \
# 89              Avatar: The Way of Water           0.209091
# 193    The Hobbit: An Unexpected Journey           0.072727
# 64                        Mortal Engines           0.054545
# 121  The Hobbit: The Desolation of Smaug           0.050000
# 104                           Glenn Levy           0.018182
# 52                          Andy McLaren           0.018182
# 95                            Tim Willis           0.013636
# 114                         Gemma Weston           0.013636
# 127                          Cody Dysart           0.013636
# 208                             Bob Buck           0.013636
#
#      Betweenness Centrality  Closeness Centrality  Eigenvector Centrality
# 89                 0.458991              0.234792                0.611709
# 193                0.184783              0.233794                0.174118
# 64                 0.012037              0.198377                0.170540
# 121                0.078806              0.220662                0.148908
# 104                0.024080              0.223577                0.146068
# 52                 0.053650              0.238095                0.137099
# 95                 0.018934              0.223124                0.123531
# 114                0.018934              0.223124                0.123531
# 127                0.018934              0.223124                0.123531
# 208                0.018934              0.223124                0.123531

# %%
#Plot the various centrality measures
plt.figure(figsize=(12, 6))
sns.boxplot(data=centrality_df[['Degree Centrality', 'Betweenness Centrality', 'Closeness Centrality', 'Eigenvector Centrality']])
plt.title("Distribution of Centrality Measures")
plt.show()

# %% [markdown]
# All in all, it seems Avatar: The Way of Water has a rather interesting amount of connections in the movie industry. I find it interesting that 4 of the top 10 impactful nodes are movies, whereas 6 are people. I also find it rather interesting that all of the movies are blockbuster movies that were highly advertised. Interestingly enough, I really don't recognize many of the actor names, but when you look them up, you find a high degree of connection to each of the 4 listed movies.
